# %%
from src.model import PyTradeShifts
from src.utils import get_distance_matrix
from scipy.stats import linregress
from src.preprocessing import main as preprocessing_main
import os
import pandas as pd
import numpy as np

data_dir = os.path.join(os.path.dirname(os.getcwd()))
os.chdir(data_dir)

# %%
years_to_consider = list(range(1993, 2023))
crops_to_consider = ["Maize (corn)", "Wheat", "Rice, paddy (rice milled equivalent)", "Soya beans"]
#crops_to_consider = ["Rice, paddy (rice milled equivalent)"]

# %%
run_preprocessing = True
if run_preprocessing:
    for year in years_to_consider:
        print(year)
        for crop in crops_to_consider:
            preprocessing_main(region="All_Data", item=crop, year="Y" + str(year))
# Out:
# 1993
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 1994
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 1995
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 1996
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 1997
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 1998
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 1999
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2000
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2001
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2002
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2003
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2004
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2005
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2006
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2007
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2008
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2009
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2010
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2011
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2012
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2013
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2014
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2015
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2016
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2017
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2018
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2019
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2020
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2021
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# 2022
# Reading in data for Maize (corn) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Wheat in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Rice, paddy (rice milled equivalent) in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data
# Reading in data for Soya beans in All_Data...
# Started to format production data
# Filter production vector
# Finished filtering production vector
# Finished formatting production data
#
# Started to format trade data
# Filter trade matrix
# Finished filtering trade matrix
# Pivot trade matrix
# Finished pivoting trade matrix
# Finished formatting trade data
#
# Unify indices
# Finished unifying indices
# Replacing country codes with country names in Trade data
# Replacing country codes with country names in Production data

# %%
def get_matrices(crop, year):
    """Get trade and distance matrices for the global wheat trade in 2018."""
    crop_trade = PyTradeShifts(
        crop,
        year,
        region="Global",
        testing=True,
        make_plot=False,
    )
    
    crop_trade.load_data()
    crop_trade.remove_net_zero_countries()
    crop_trade.prebalance()
    crop_trade.correct_reexports()
    np.fill_diagonal(crop_trade.trade_matrix.values, 0)

    dm = get_distance_matrix(
        crop_trade.trade_matrix.index, crop_trade.trade_matrix.columns
    )
    return crop_trade.trade_matrix, dm

# %%
def get_xy_from_matrices(tm, dm):
    """Get x and y values from trade and distance matrices."""
    # a little melting trick, this will produce:
    # a df with three columns: country A, country B, volume of trade from A to B
    tm = tm.stack().reset_index()
    # a df with three columns: country A, country B, distance from A to B
    dm = dm.stack().reset_index()
    # index order should match because tm and dm should have the same index/columns
    # so we can just take the values and roll with it
    # otherwise we should do a formal join here
    y = tm[0].values
    x = dm[0].values
    # filter out zeroes
    x = x[y != 0]
    y = y[y != 0]
    # sort values by distance
    y = y[x.argsort()]
    x = x[x.argsort()]
    return x, y

# %% [markdown]
# We use the approach from [Karpiarz et al.](https://arxiv.org/pdf/1409.5963.pdf) (Fig. 1), since it is beyond the scope of our work to assess and validate the (well-established) gravity model.
#
# We do not trouble ourselves with questioning whether it is or isn't a "proper" power-law etc., we only focus on obtaining comparible quantities to the work present in the above paper.
#
# For a more advanced approach to power-law fitting see [Clauset et al.](https://arxiv.org/pdf/0706.1062.pdf)

# %%
def get_vr(x, y):
    # integrate over distance
    vr = np.cumsum(y[::-1])[::-1] 
    return vr

# %%
def get_best_fit(x, vr):
    # convert to log-log
    x = np.log(x)
    vr = np.log(vr)
    # find the best fit in a reasonable range
    # in theory we could run this for each possible segment (computationally insane)
    # but a) we want to start from index 0 (we're interested in highest trade volume the most)
    # and b) we need to make sure we do not take too few points, becasue we risk overfitting
    best_r = 0
    best_a = 0
    best_b = 0
    best_end_of_lin = 0
    for end_of_lin in np.arange(100, 4001, 1):
        slope, intercept, r, p, stderr = linregress(x[0:end_of_lin], vr[0:end_of_lin])
        if r**2 > best_r:
            best_r = r**2
            best_a = slope
            best_b = intercept
            best_end_of_lin = end_of_lin

    # print the result, we print a+1 because the slope fitted to the integral
    # is a - 1 where a is the coefficient in the trade data
    return best_end_of_lin, best_r, 1-best_a

# %%
# Create a dataframe with the years as the index and the crops as the columns
results = {}
for year in years_to_consider:
    results[year] = {}
    for crop in crops_to_consider:
        if crop == "Maize (corn)": crop = "Maize"
        if crop == "Rice, paddy (rice milled equivalent)": crop = "Rice"
        tm, dm = get_matrices(crop, year)
        x, y = get_xy_from_matrices(tm, dm)
        vr = get_vr(x, y)
        best_end_of_lin, best_r, best_a = get_best_fit(x, vr)
        results[year][crop] = best_a

# make the dataframe
df = pd.DataFrame(results).transpose()
# Save the dataframe
df.to_csv("results" +os.sep + "gravity_exponent.csv")
# Out:
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y1993.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y1993.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Rice in Y1993.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y1993.
# Removed 8 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y1994.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y1994.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 2 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Loaded data for Rice in Y1994.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y1994.
# Removed 6 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y1995.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y1995.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y1995.
# Removed 3 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Loaded data for Soya beans in Y1995.
# Removed 15 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 2 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y1996.
# Removed 3 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y1996.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y1996.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Loaded data for Soya beans in Y1996.
# Removed 8 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y1997.
# Removed 3 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y1997.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y1997.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y1997.
# Removed 8 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 2 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y1998.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y1998.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y1998.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y1998.
# Removed 9 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 2 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y1999.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y1999.
# Removed 3 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y1999.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y1999.
# Removed 3 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 3 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2000.
# Removed 3 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2000.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2000.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2000.
# Removed 8 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2001.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2001.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2001.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Loaded data for Soya beans in Y2001.
# Removed 3 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 3 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2002.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2002.
# Removed 4 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2002.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2002.
# Removed 7 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2003.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2003.
# Removed 8 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2003.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2003.
# Removed 5 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 3 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2004.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2004.
# Removed 4 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2004.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2004.
# Removed 5 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2005.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2005.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2005.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2005.
# Removed 8 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2006.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2006.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2006.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2006.
# Removed 10 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2007.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2007.
# Removed 3 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2007.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2007.
# Removed 6 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 3 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2008.
# Removed 3 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2008.
# Removed 6 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2008.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2008.
# Removed 13 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 2 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2009.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2009.
# Removed 4 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2009.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2009.
# Removed 10 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2010.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2010.
# Removed 6 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2010.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2010.
# Removed 12 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2011.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2011.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2011.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2011.
# Removed 8 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2012.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2012.
# Removed 4 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2012.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2012.
# Removed 14 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2013.
# Removed 3 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2013.
# Removed 5 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2013.
# Removed 2 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2013.
# Removed 12 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2014.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2014.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2014.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2014.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2015.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2015.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2015.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2015.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2016.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2016.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2016.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2016.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2017.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2017.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2017.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2017.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 5 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2018.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2018.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2018.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2018.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2019.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2019.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2019.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2019.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2020.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2020.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2020.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2020.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2021.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Wheat in Y2021.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2021.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2021.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Maize in Y2022.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Attempting to invert the matrix again.
# Corrected re-exports.
# Loaded data for Wheat in Y2022.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Warning: trade matrix has duplicate indices, which will be removed.
# The duplicates are the following:
# Index(['Micronesia, Fed. Sts.', 'Micronesia, Fed. Sts.'], dtype='object')
# Loaded data for Rice in Y2022.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Loaded data for Soya beans in Y2022.
# Removed 0 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.

# %%
df = pd.read_csv("results" +os.sep + "gravity_exponent.csv", index_col=0)

# %%
df.plot(kind="bar", title="Gravity exponent for different crops and years", subplots=True, layout=(2, 2), figsize=(10, 5), legend=False)
# Out:
# array([[<Axes: title={'center': 'Maize'}>,
#         <Axes: title={'center': 'Wheat'}>],
#        [<Axes: title={'center': 'Rice'}>,
#         <Axes: title={'center': 'Soya beans'}>]], dtype=object)
