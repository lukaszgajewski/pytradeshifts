# %%
from src.model import PyTradeShifts
from src.postprocessing import Postprocessing
import pandas as pd
import os
os.chdir('../../')
print(os.getcwd())
# Out:
# /home/florian/Documents/GitHub/pytradeshifts

# %% [markdown]
# First let's compare the overall structure of the data. How many countries are affected in the scenario and by how much?

# %%
LoI_data = pd.read_csv("data/scenario_files/losing_industry/Wheat2mean_values.csv")
print("The average yield reduction globally for global catastrophic infrastructure is: ", LoI_data["mean_value"].mean())
print("This considers n = ", len(LoI_data), " countries")
# Out:
# The average yield reduction globally for global catastrophic infrastructure is:  -34.79496316270323
# This considers n =  94  countries

# %%
NW_data = pd.read_csv("data/scenario_files/nuclear_winter/xia_47tg_y3_swheat.csv")
print("The average yield reduction globally for nuclear winter is: ", NW_data["47tg"].mean())
print("This considers n = ", len(NW_data), " countries")
# Out:
# The average yield reduction globally for nuclear winter is:  -35.93313559322034
# This considers n =  118  countries

# %% [markdown]
# Next we calculate the trade communities for our base scenario as well as global catastrophic infrastructure loss and abrupt sunlight reduction.

# %%
base_year = 2022
Wheat_base = PyTradeShifts(
    "Wheat",
    base_year=base_year,
    region="Global",
    testing=False,
    cd_kwargs={"seed": 2},
    make_plot=False,
)
loss_of_industry = PyTradeShifts(
    crop="Wheat",
    base_year=base_year,
    scenario_file_name="losing_industry/Wheat2mean_values.csv",
    scenario_name="Global Catastrophic Infrastructure Loss",
    cd_kwargs={"seed": 2},
    make_plot=False,
)
asrs = PyTradeShifts(
    crop="Wheat",
    base_year=base_year,
    scenario_file_name="nuclear_winter/xia_47tg_y3_swheat.csv",
    scenario_name="Abrupt Sunlight Reduction Scenario",
    cd_kwargs={"seed": 2},
    make_plot=False,
)
# Out:
# Loaded data for Wheat in Y2022.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Removed countries with trade below the 75th percentile.
# Built trade graph.
# Found 6 trade communities.
# Loaded data for Wheat in Y2022.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Removed countries with trade below the 75th percentile.
# Applied scenario Global Catastrophic Infrastructure Loss.
# Built trade graph.
# Found 6 trade communities.
# Loaded data for Wheat in Y2022.
# Removed 1 countries with no trade or production.
# Prebalanced trade matrix.
# Corrected re-exports.
# Removed countries with trade below the 75th percentile.
# Applied scenario Abrupt Sunlight Reduction Scenario.
# Built trade graph.
# Found 6 trade communities.

# %% [markdown]
# To compare the scenario to each other, we have to do a bunch of additional calculations. These all happen in the postprocessing class. Anchor countries are user-specified list of countries that the script attempts to keep the same colour between scenarios.

# %%
comparison = Postprocessing([Wheat_base, loss_of_industry, asrs], anchor_countries=["Brazil", "United States", "Russia", "Uzbekistan" "Germany"])
# Out:
# Starting postprocessing computations...
# /home/florian/Documents/GitHub/pytradeshifts/src/postprocessing.py:183: RuntimeWarning: invalid value encountered in scalar divide
#   (imports[country] - self.imports[0][country]) / self.imports[0][country]

# %%
comparison.plot_imports_difference(vmin=-100, vmax=0)

# %% [markdown]
# Next lets look at how the trade communities change globally in the different scenarios.

# %%
comparison.plot_all_trade_communities()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 comparison.plot_all_trade_communities()
#
# File ~/Documents/GitHub/pytradeshifts/src/postprocessing.py:910, in Postprocessing.plot_all_trade_communities(self, figsize, file_path, file_format, dpi)
#     908     axs = [axs]
#     909 for ax, scenario in zip(axs, self.scenarios):
# --> 910     scenario._plot_trade_communities(ax)
#     911 if file_path:
#     912     plt.savefig(
#     913         f"{file_path}{os.sep}trade_communities.{file_format}",
#     914         dpi=dpi,
#     915         bbox_inches="tight",
#     916     )
#
# File ~/Documents/GitHub/pytradeshifts/src/model.py:787, in PyTradeShifts._plot_trade_communities(self, ax)
#     776 cmap = ListedColormap(
#     777     sns.color_palette("deep", len(self.trade_communities)).as_hex()
#     778 )
#     779 world.plot(
#     780     ax=ax,
#     781     column="community",
#    (...)
#     784     legend=False,
#     785 )
# --> 787 plot_winkel_tripel_map(ax)
#     788 # Add the countries which were removed from the trade matrix as shaded
#     789 # countries
#     790 if self.countries_to_remove is not None and self.shade_removed_countries:
#     791     # Convert the country names to the same format as in the trade matrix
#
# File ~/Documents/GitHub/pytradeshifts/src/utils.py:19, in plot_winkel_tripel_map(ax)
#      15 def plot_winkel_tripel_map(ax: Axes):
#      16     """
#      17     Helper function to plot a Winkel Tripel map with a border.
#      18     """
# ---> 19     border_geojson = gpd.read_file(
#      20         "https://raw.githubusercontent.com/ALLFED/ALLFED-map-border/main/border.geojson"
#      21     )
#      22     border_geojson.plot(ax=ax, edgecolor="black", linewidth=0.1, facecolor="none")
#      23     ax.grid(False)
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/geopandas/io/file.py:281, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     275 from_bytes = False
#     276 if _is_url(filename):
#     277     # if it is a url that supports random access -> pass through to
#     278     # pyogrio/fiona as is (to support downloading only part of the file)
#     279     # otherwise still download manually because pyogrio/fiona don't support
#     280     # all types of urls (https://github.com/geopandas/geopandas/issues/2908)
# --> 281     with urllib.request.urlopen(filename) as response:
#     282         if not response.headers.get("Accept-Ranges") == "bytes":
#     283             filename = response.read()
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/urllib/request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/urllib/request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/urllib/request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346     except OSError as err: # timeout error
#    1347         raise URLError(err)
# -> 1348     r = h.getresponse()
#    1349 except:
#    1350     h.close()
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/http/client.py:1423, in HTTPConnection.getresponse(self)
#    1421 try:
#    1422     try:
# -> 1423         response.begin()
#    1424     except ConnectionError:
#    1425         self.close()
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# We can also try to quantify how different the communities are in each scenario for each country.
# The natural way of doing this is the [Jaccard index](https://en.wikipedia.org/wiki/Jaccard_index)
# It measures the similarity between two sets.
# So for each country we can compute a Jaccard distance (1-Jaccard index)
# showing us by how much for each country their community changed in comparison with the base scenario.

# %%
comparison.plot_community_difference(vmin=0, vmax=1)

# %%
comparison.plot_roles()

# %% [markdown]
# We can also study the degree centralities (in and out) for all networks:

# %%
comparison.plot_centrality_maps(figsize=(5, 25), shrink=0.2, vmin=0, vmax=0.15)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 comparison.plot_centrality_maps(figsize=(5, 25), shrink=0.2, vmin=0, vmax=0.15)
#
# File ~/Documents/GitHub/pytradeshifts/src/postprocessing.py:672, in Postprocessing.plot_centrality_maps(self, figsize, shrink, file_path, file_format, dpi, **kwargs)
#     661 for scenario, in_degree, out_degree in zip(
#     662     self.scenarios, self.in_degree, self.out_degree
#     663 ):
#     664     plot_node_metric_map(
#     665         axs[idx],
#     666         scenario,
#    (...)
#     670         **kwargs,
#     671     )
# --> 672     plot_node_metric_map(
#     673         axs[idx + 1],
#     674         scenario,
#     675         out_degree,
#     676         "out-degree",
#     677         shrink=shrink,
#     678         **kwargs,
#     679     )
#     680     idx += 2
#     681 if file_path:
#
# File ~/Documents/GitHub/pytradeshifts/src/utils.py:276, in plot_node_metric_map(ax, scenario, metric, metric_name, shrink, **kwargs)
#     273 # Join the country_community dictionary to the world dataframe
#     274 world[metric_name] = world["names_short"].map(metric)
# --> 276 world.plot(
#     277     ax=ax,
#     278     column=metric_name,
#     279     missing_kwds={"color": "lightgrey"},
#     280     legend=True,
#     281     legend_kwds={
#     282         "label": metric_name,
#     283         "shrink": shrink,
#     284     },
#     285     **kwargs,
#     286 )
#     288 plot_winkel_tripel_map(ax)
#     290 # Add a title with self.scenario_name if applicable
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/geopandas/plotting.py:979, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     977 kind = kwargs.pop("kind", "geo")
#     978 if kind == "geo":
# --> 979     return plot_dataframe(data, *args, **kwargs)
#     980 if kind in self._pandas_kinds:
#     981     # Access pandas plots
#     982     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/geopandas/plotting.py:901, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     898     merged_kwds = style_kwds.copy()
#     899     merged_kwds.update(missing_kwds)
# --> 901     plot_series(expl_series[nan_idx], ax=ax, **merged_kwds)
#     903 if legend and not color:
#     904     if legend_kwds is None:
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/geopandas/plotting.py:494, in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     488     color_ = expl_color[point_idx] if color_given else color
#     490     _plot_point_collection(
#     491         ax, points, values_, color=color_, cmap=cmap, **style_kwds
#     492     )
# --> 494 plt.draw()
#     495 return ax
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/pyplot.py:1111, in draw()
#    1094 def draw() -> None:
#    1095     """
#    1096     Redraw the current figure.
#    1097
#    (...)
#    1109     .FigureCanvasBase.draw
#    1110     """
# -> 1111     gcf().canvas.draw_idle()
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/axis.py:1391, in Axis.draw(self, renderer, *args, **kwargs)
#    1388 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1390 for tick in ticks_to_draw:
# -> 1391     tick.draw(renderer)
#    1393 # Shift label away from axes to avoid overlapping ticklabels.
#    1394 self._update_label_position(renderer)
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/axis.py:295, in Tick.draw(self, renderer)
#     292 renderer.open_group(self.__name__, gid=self.get_gid())
#     293 for artist in [self.gridline, self.tick1line, self.tick2line,
#     294                self.label1, self.label2]:
# --> 295     artist.draw(renderer)
#     296 renderer.close_group(self.__name__)
#     297 self.stale = False
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/lines.py:746, in Line2D.draw(self, renderer)
#     743     return
#     745 if self._invalidy or self._invalidx:
# --> 746     self.recache()
#     747 self.ind_offset = 0  # Needed for contains() method.
#     748 if self._subslice and self.axes:
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/lines.py:673, in Line2D.recache(self, always)
#     671     x = self._x
#     672 if always or self._invalidy:
# --> 673     yconv = self.convert_yunits(self._yorig)
#     674     y = _to_unmasked_float_array(yconv).ravel()
#     675 else:
#
# File ~/local/anaconda3/envs/pytradeshifts/lib/python3.12/site-packages/matplotlib/artist.py:288, in Artist.convert_yunits(self, y)
#     281 def convert_yunits(self, y):
#     282     """
#     283     Convert *y* using the unit type of the yaxis.
#     284
#     285     If the artist is not contained in an Axes or if the yaxis does not
#     286     have units, *y* itself is returned.
#     287     """
# --> 288     ax = getattr(self, 'axes', None)
#     289     if ax is None or ax.yaxis is None:
#     290         return y
#
# KeyboardInterrupt:

# %% [markdown]
# and in tabulated form, global:

# %%
comparison.print_global_centrality_metrics(index=False)
# Out:
# ***| Degree centrality metrics for each scenario |***
# ╒═════════════╤═════════════╤═════════════╤═════════════╤══════════════╤══════════════╤══════════════╤══════════════╕
# │ Smallest    │    Smallest │ Largest     │     Largest │ Smallest     │     Smallest │ Largest      │      Largest │
# │ in-degree   │   in-degree │ in-degree   │   in-degree │ out-degree   │   out-degree │ out-degree   │   out-degree │
# │ country     │       value │ country     │       value │ country      │        value │ country      │        value │
# ╞═════════════╪═════════════╪═════════════╪═════════════╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ Argentina   │           0 │ China       │   0.0607331 │ Afghanistan  │            0 │ Australia    │     0.162048 │
# ├─────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼──────────────┼──────────────┤
# │ Argentina   │           0 │ Türkiye     │   0.0618672 │ Afghanistan  │            0 │ Australia    │     0.173626 │
# ├─────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼──────────────┼──────────────┤
# │ Argentina   │           0 │ China       │   0.0898626 │ Afghanistan  │            0 │ Australia    │     0.355417 │
# ╘═════════════╧═════════════╧═════════════╧═════════════╧══════════════╧══════════════╧══════════════╧══════════════╛

# %% [markdown]
# and for each community in each scenario. Note: the community ID doesn't mean much, it is just the index in the list scenario.trade_communities

# %%
comparison.print_per_community_centrality_metrics(index=False)
# Out:
# ***| Degree centrality metrics for the scenario with ID: 0 |***
# ╒══════════════╤═════════════╤═════════════╤═════════════╤══════════════╤══════════════╤═══════════════╤══════════════╕
# │ Smallest     │    Smallest │ Largest     │     Largest │ Smallest     │     Smallest │ Largest       │      Largest │
# │ in-degree    │   in-degree │ in-degree   │   in-degree │ out-degree   │   out-degree │ out-degree    │   out-degree │
# │ country      │       value │ country     │       value │ country      │        value │ country       │        value │
# ╞══════════════╪═════════════╪═════════════╪═════════════╪══════════════╪══════════════╪═══════════════╪══════════════╡
# │ Argentina    │ 0           │ Nigeria     │   0.0276539 │ Angola       │            0 │ Argentina     │    0.0728485 │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Sierra Leone │ 2.83109e-06 │ Japan       │   0.0294449 │ Bahamas      │            0 │ United States │    0.113385  │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Ukraine      │ 0           │ Türkiye     │   0.0497219 │ Azerbaijan   │            0 │ Russia        │    0.100281  │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Australia    │ 1.73156e-06 │ China       │   0.0607331 │ Bahrain      │            0 │ Australia     │    0.162048  │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Slovenia     │ 0           │ Algeria     │   0.0395108 │ Albania      │            0 │ France        │    0.11263   │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Turkmenistan │ 0.00189496  │ Uzbekistan  │   0.0169669 │ Afghanistan  │            0 │ Kazakhstan    │    0.0324642 │
# ╘══════════════╧═════════════╧═════════════╧═════════════╧══════════════╧══════════════╧═══════════════╧══════════════╛
# ***| Degree centrality metrics for the scenario with ID: 1 |***
# ╒══════════════╤═════════════╤═════════════╤═════════════╤══════════════╤══════════════╤═══════════════╤══════════════╕
# │ Smallest     │    Smallest │ Largest     │     Largest │ Smallest     │     Smallest │ Largest       │      Largest │
# │ in-degree    │   in-degree │ in-degree   │   in-degree │ out-degree   │   out-degree │ out-degree    │   out-degree │
# │ country      │       value │ country     │       value │ country      │        value │ country       │        value │
# ╞══════════════╪═════════════╪═════════════╪═════════════╪══════════════╪══════════════╪═══════════════╪══════════════╡
# │ Argentina    │ 0           │ Brazil      │   0.0285957 │ Angola       │            0 │ Argentina     │    0.0839834 │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Sierra Leone │ 2.62045e-06 │ Japan       │   0.0286387 │ Bahamas      │            0 │ United States │    0.108463  │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Ukraine      │ 0           │ Türkiye     │   0.0618672 │ Azerbaijan   │            0 │ Russia        │    0.135783  │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Australia    │ 1.42799e-06 │ China       │   0.0591254 │ Bahrain      │            0 │ Australia     │    0.173626  │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Slovenia     │ 0           │ Algeria     │   0.0335271 │ Albania      │            0 │ France        │    0.0720128 │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Malta        │ 0.000112703 │ Uzbekistan  │   0.0263765 │ Afghanistan  │            0 │ Kazakhstan    │    0.051174  │
# ╘══════════════╧═════════════╧═════════════╧═════════════╧══════════════╧══════════════╧═══════════════╧══════════════╛
# ***| Degree centrality metrics for the scenario with ID: 2 |***
# ╒══════════════╤═════════════╤═════════════╤═════════════╤══════════════╤══════════════╤═══════════════╤══════════════╕
# │ Smallest     │    Smallest │ Largest     │     Largest │ Smallest     │     Smallest │ Largest       │      Largest │
# │ in-degree    │   in-degree │ in-degree   │   in-degree │ out-degree   │   out-degree │ out-degree    │   out-degree │
# │ country      │       value │ country     │       value │ country      │        value │ country       │        value │
# ╞══════════════╪═════════════╪═════════════╪═════════════╪══════════════╪══════════════╪═══════════════╪══════════════╡
# │ Argentina    │ 0           │ Brazil      │  0.0348528  │ Botswana     │            0 │ Argentina     │    0.111919  │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Sierra Leone │ 2.46049e-08 │ Mexico      │  0.0182525  │ Bahamas      │            0 │ United States │    0.0835593 │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Slovenia     │ 0           │ Algeria     │  0.0491195  │ Albania      │            0 │ France        │    0.125427  │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Australia    │ 3.0881e-06  │ China       │  0.0898626  │ Bahrain      │            0 │ Australia     │    0.355417  │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Bhutan       │ 2.62765e-05 │ Bangladesh  │  0.0326585  │ Bangladesh   │            0 │ India         │    0.071639  │
# ├──────────────┼─────────────┼─────────────┼─────────────┼──────────────┼──────────────┼───────────────┼──────────────┤
# │ Kazakhstan   │ 0.000594395 │ Uzbekistan  │  0.00553107 │ Afghanistan  │            0 │ Kazakhstan    │    0.011382  │
# ╘══════════════╧═════════════╧═════════════╧═════════════╧══════════════╧══════════════╧═══════════════╧══════════════╛

# %% [markdown]
# We can plot a community satisfaction index, taken from [here](https://www.mdpi.com/2304-8158/12/2/271).
#
# It measures how much of each country's import is satisfied by their community.

# %%
comparison.plot_community_satisfaction(figsize=(10, 10))

# %% [markdown]
# and the difference from base scenario:

# %%
comparison.plot_community_satisfaction_difference(figsize=(7.5, 7.5), vmin=-1, vmax=1, cmap="coolwarm_r")

# %% [markdown]
# We also can look at country's stability index, which is a measure of how easily each country can replace their import partners (same paper as community satisfaction).

# %%
comparison.plot_node_stability(vmin=0, vmax=0.0003) # figsize works here too of course

# %% [markdown]
# The units are dimensionless, so it is better to look at the relative change of the node stability to get a better view.
# For this reason we can look at the *relative* change of this metric:

# %%
comparison.plot_node_stability_difference(figsize=(10, 10), vmin=-0.5, vmax=0.5, cmap="coolwarm_r")

# %% [markdown]
# Another important aspect of a network is its resilience to attacks, and we can see that as well:

# %%
comparison.plot_attack_resilience(exclude_attacks="entropic")

# %% [markdown]
# This is based on [this paper](https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.100.058701).
#
# In there, the authors show that we can approximate the network percolation threshold with the largest eigenvalue of a particular matrix (details in paper/code docs).
#
# We consider three modes of attack: export based, entropic degree based, and random.
#
# Export based means that we remove nodes in order of their out-degree (relative exporting importance), highest to lowest.
#
# Random means we remove the nodes at random. This also requires us to recompute this many times to get decent statistic (controlled by a parameter passed to postprocessing class). That's why the 'random' curves have error bands and a '+/-' next to their threshold value.
# The error band and threshold error is controlled by a sigma parameter (passed directly to the function). By default we're computing a [2-sigma result](https://en.wikipedia.org/wiki/68%E2%80%9395%E2%80%9399.7_rule).
#
# In the legedn: ID refers to the scenario ID as passed into the postprocessing class, next is the attack type and finally the threshold value. This threshold tells us how many nodes need to be removed to collapse the network.

# %%
comparison.print_network_metrics()
# Out:
# ╒═══════════════╤═══════════════╤══════════════╤══════════════╤═══════════════════╤═════════════════╤═════════════════╤═════════════╕
# │   Scenario ID │   Betweenness │   Clustering │   Efficiency │   Entropic-attack │   Export-attack │ Random-attack   │   Stability │
# │               │               │              │              │         threshold │       threshold │ threshold       │             │
# ╞═══════════════╪═══════════════╪══════════════╪══════════════╪═══════════════════╪═════════════════╪═════════════════╪═════════════╡
# │             0 │    0.00463187 │  0.00289272  │     0.129134 │                37 │              38 │ 1.5e+02 +/- 1.2 │ 0.000129036 │
# ├───────────────┼───────────────┼──────────────┼──────────────┼───────────────────┼─────────────────┼─────────────────┼─────────────┤
# │             1 │    0.00477852 │  0.00239208  │     0.115993 │                38 │              40 │ 1.5e+02 +/- 1.1 │ 0.000111407 │
# ├───────────────┼───────────────┼──────────────┼──────────────┼───────────────────┼─────────────────┼─────────────────┼─────────────┤
# │             2 │    0.00388273 │  0.000384904 │     0.139314 │                37 │              39 │ 1.5e+02 +/- 1.2 │ 0.000118081 │
# ╘═══════════════╧═══════════════╧══════════════╧══════════════╧═══════════════════╧═════════════════╧═════════════════╧═════════════╛
