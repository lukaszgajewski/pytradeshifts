# %%
from src.model import PyTradeShifts
from src.postprocessing import Postprocessing
import pandas as pd
import os
os.chdir('../../')
print(os.getcwd())
# Out:
# /home/florian/Documents/GitHub/pytradeshifts

# %%
y2018 = PyTradeShifts(
    "Wheat",
    base_year=2018,
    region="Global",
    testing=False,
    cd_kwargs={"seed": 2},
    make_plot=False,
    keep_singletons=True
)
y2019 = PyTradeShifts(
    "Wheat",
    base_year=2019,
    region="Global",
    testing=False,
    cd_kwargs={"seed": 2},
    make_plot=False,
    keep_singletons=True
)
y2020 = PyTradeShifts(
    "Wheat",
    base_year=2020,
    region="Global",
    testing=False,
    cd_kwargs={"seed": 2},
    make_plot=False,
    keep_singletons=True
)
y2021 = PyTradeShifts(
    "Wheat",
    base_year=2021,
    region="Global",
    testing=False,
    cd_kwargs={"seed": 2},
    make_plot=False,
    keep_singletons=True
)
y2022 = PyTradeShifts(
    "Wheat",
    base_year=2022,
    region="Global",
    testing=False,
    cd_kwargs={"seed": 2},
    make_plot=False,
    keep_singletons=True
)
# Out:
# Loaded data for Wheat in Y2018.
# Removed 0 countries with no trade or production.
# No countries removed.
# Prebalanced trade matrix.
# Corrected re-exports.
# Removed countries with trade below the 75th percentile.
# Built trade graph.
# Found 6 trade communities.
# Keeping communities with only one country.
# Loaded data for Wheat in Y2019.
# Removed 0 countries with no trade or production.
# No countries removed.
# Prebalanced trade matrix.
# Corrected re-exports.
# Removed countries with trade below the 75th percentile.
# Built trade graph.
# Found 6 trade communities.
# Keeping communities with only one country.
# Loaded data for Wheat in Y2020.
# Removed 0 countries with no trade or production.
# No countries removed.
# Prebalanced trade matrix.
# Determinant=0 encountered in PyTradeShifts.correct_reexports().
# Re-applying PyTradeShifts.remove_net_zero_countries().
# Removed 1 countries with no trade or production.
# Removed countries: ['St. Kitts and Nevis']
# Attempting to invert the matrix again.
# Corrected re-exports.
# Removed countries with trade below the 75th percentile.
# Built trade graph.
# Found 5 trade communities.
# Keeping communities with only one country.
# Loaded data for Wheat in Y2021.
# Removed 1 countries with no trade or production.
# Removed countries: ['South Sudan']
# Prebalanced trade matrix.
# Corrected re-exports.
# Removed countries with trade below the 75th percentile.
# Built trade graph.
# Found 7 trade communities.
# Keeping communities with only one country.
# Loaded data for Wheat in Y2022.
# Removed 1 countries with no trade or production.
# Removed countries: ['South Sudan']
# Prebalanced trade matrix.
# Corrected re-exports.
# Removed countries with trade below the 75th percentile.
# Built trade graph.
# Found 6 trade communities.
# Keeping communities with only one country.

# %%
comparison = Postprocessing([y2018, y2019, y2020, y2021, y2022], anchor_countries=["Brazil", "United States", "Russia", "Uzbekistan" "Germany"])
# Out:
# Starting postprocessing computations...
# Warning: Comoros not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Marshall Islands not found in the base scenario.
# Warning: Niger not found in the base scenario.
# Warning: Bhutan not found in the base scenario.
# Warning: Chad not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Bahamas not found in the base scenario.
# Warning: Bhutan not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Sierra Leone not found in the base scenario.
# Warning: Bahamas not found in the base scenario.
# Warning: Bhutan not found in the base scenario.
# Warning: Central African Republic not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Sierra Leone not found in the base scenario.
# Warning: Palestine has no community in scenario 1.
# Warning: Eritrea has no community in scenario 2.
# Warning: Palestine has no community in scenario 2.
# Warning: North Korea has no community in scenario 3.
# Warning: Bolivia has no community in scenario 4.
# Warning: Cambodia has no community in scenario 4.
# Warning: Laos has no community in scenario 4.
# Warning: North Korea has no community in scenario 4.
# Warning: Palestine has no community in scenario 4.
# Warning: Comoros not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Marshall Islands not found in the base scenario.
# Warning: Niger not found in the base scenario.
# Warning: Bhutan not found in the base scenario.
# Warning: Chad not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Bahamas not found in the base scenario.
# Warning: Bhutan not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Sierra Leone not found in the base scenario.
# Warning: Bahamas not found in the base scenario.
# Warning: Bhutan not found in the base scenario.
# Warning: Central African Republic not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Sierra Leone not found in the base scenario.
# Warning: Comoros not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Marshall Islands not found in the base scenario.
# Warning: Niger not found in the base scenario.
# Warning: Bhutan not found in the base scenario.
# Warning: Chad not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Bahamas not found in the base scenario.
# Warning: Bhutan not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Sierra Leone not found in the base scenario.
# Warning: Bahamas not found in the base scenario.
# Warning: Bhutan not found in the base scenario.
# Warning: Central African Republic not found in the base scenario.
# Warning: Madagascar not found in the base scenario.
# Warning: Sierra Leone not found in the base scenario.

# %%
comparison.plot_all_trade_communities(figsize=(15, 10))

# %%
comparison.plot_community_difference(figsize=(10, 10), vmin=0, vmax=1)

# %%
comparison.plot_roles()

# %%
comparison.plot_imports_difference(figsize=(10, 10), vmin=-100, vmax=100, cmap="coolwarm")
